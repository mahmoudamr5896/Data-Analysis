# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Top 50 Youtube Channels.csv')

# %%
df
# Out:
#     Rank                                       Channel name  \
# 0      1                                           T-Series
# 1      2                         Cocomelon - Nursery Rhymes
# 2      3                                          SET India
# 3      4                                           Sony SAB
# 4      5                                        Like Nastya
# 5      6                                    Kids Diana Show
# 6      7                                                WWE
# 7      8                                      Vlad and Niki
# 8      9                                         Movieclips
# 9     10                                          Colors TV
# 10    11                                       Ryan's World
# 11    12                                         netd müzik
# 12    13                                  El Reino Infantil
# 13    14                                  Zee Music Company
# 14    15                              ABS-CBN Entertainment
# ...

# %%
df['Content\ncategory'].value_counts()
# Out:
# Music            22
# Entertainment    17
# Education         6
# Film              2
# Sports            1
# Gaming            1
# News              1
# Name: Content\ncategory, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# India             14
# United States     10
# Russia             3
# South Korea        3
# Canada             3
# Philippines        2
# United Kingdom     2
# Thailand           2
# Pakistan           2
# Sweden             1
# Jordan             1
# Puerto Rico        1
# Brazil             1
# Romania            1
# Argentina          1
# Turkey             1
# Ukraine            1
# Kyrgyzstan         1
# Name: Country, dtype: int64

# %%
df['Primary language(s)'].value_counts()
# Out:
# English                 18
# Hindi                   12
# Korean                   3
# Spanish                  2
# Filipino and English     2
# Thai                     2
# Russian                  2
# Urdu                     2
# Russian and English      1
# Turkish                  1
# Hindi and English        1
# Bhojpuri                 1
# Portuguese               1
# Arabic                   1
# Name: Primary language(s), dtype: int64

# %%
plt.bar(df['Content\ncategory'],df['Views\n(billions)'],width=.5,bottom=9)
plt.figure(figsize=(20,10))

# %%
df.isna().sum()
# Out:
# Rank                   0
# Channel name           0
# Network                3
# Views\n(billions)      0
# Content\ncategory      0
# Country                0
# Primary language(s)    1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 50 non-null     int64
#  1   Channel name         50 non-null     object
#  2   Network              47 non-null     object
#  3   Views
# (billions)     50 non-null     float64
#  4   Content
# category     50 non-null     object
#  5   Country              50 non-null     object
#  6   Primary language(s)  49 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
df.columns
# Out:
# Index(['Rank', 'Channel name', 'Network', 'Views\n(billions)',
#        'Content\ncategory', 'Country', 'Primary language(s)'],
#       dtype='object')

# %%
df['Views\n(billions)'].max()
# Out:
# 209.23

# %%
df_n=df[['Channel name','Views\n(billions)','Content\ncategory','Country','Primary language(s)']]

# %%
df_o=df[['Channel name','Views\n(billions)','Content\ncategory']]

# %%
df_m=df_n[['Country','Views\n(billions)']]

# %%
df_m['Country']=df_m['Country'].astype('string')
# Out:
# C:\Users\fg\AppData\Local\Temp\ipykernel_11756\2255641843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m['Country']=df_m['Country'].astype('string')

# %%
df_m.dtypes
# Out:
# Country               string
# Views\n(billions)    float64
# dtype: object

# %%
df_m.groupby("Country")

# %%
df_m.set_index(["Country"])
# Out:
#                 Views\n(billions)
# Country
# India                      209.23
# United States              145.78
# India                      135.15
# India                       89.06
# Russia                      85.99
# Ukraine                     85.08
# United States               72.84
# United States               71.16
# United States               59.50
# India                       56.54
# United States               53.22
# Turkey                      52.73
# Argentina                   52.65
# India                       52.38
# Philippines                 49.04
# United States               43.56
# India                       41.26
# Canada                      40.04
# India                       38.43
# United Kingdom              38.29
# Brazil                      37.01
# United States               34.96
# Thailand                    34.84
# Russia                      34.10
# Pakistan                    31.02
# India                       31.00
# ...

# %%
df_m.groupby(["Country"], sort=False).sum()
# Out:
#                 Views\n(billions)
# Country
# India                      822.74
# United States              563.79
# Russia                     148.90
# Ukraine                     85.08
# Turkey                      52.73
# Argentina                   52.65
# Philippines                 76.47
# Canada                      95.19
# United Kingdom              67.01
# Brazil                      37.01
# Thailand                    61.65
# Pakistan                    61.76
# Romania                     30.42
# Sweden                      28.79
# South Korea                 80.01
# Puerto Rico                 27.30
# Jordan                      26.48
# Kyrgyzstan                  26.18

# %%
plt.plot(df_m.groupby(["Country"], sort=False).sum())

# %%
plt.scatter(df_n['Country'],df_n['Views\n(billions)'] ,
    marker=4,
    cmap=None,
    norm=4,
    vmin=4,
    vmax=None,
    alpha=None,
    linewidths=10,
    plotnonfinite=False)
