# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FIFA WC 2022 Players Stats.csv')

# %%
df
# Out:
#     Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 0      Argentina              2                    Adidas       GK
# 1      Argentina              2                    Adidas       GK
# 2      Argentina              2                    Adidas       GK
# 3      Argentina              2                    Adidas       DF
# 4      Argentina              2                    Adidas       DF
# ..           ...            ...                       ...      ...
# 809       Canada             53                      Nike       FW
# 810       Canada             53                      Nike       FW
# 811       Canada             53                      Nike       FW
# 812       Canada             53                      Nike       FW
# 813       Canada             53                      Nike       FW
#
#      National Team Jersey Number    Player DOB          Club   \
# 0                           23.0   Sep 2, 1992    Aston Villa
# ...

# %%
df.columns
# Out:
# Index(['Nationality ', 'FIFA Ranking ', 'National Team Kit Sponsor',
#        'Position', 'National Team Jersey Number', 'Player DOB', 'Club ',
#        'Player Name ', ' Appearances', 'Goals Scored ', 'Assists Provided ',
#        'Dribbles per 90', 'Interceptions per 90', 'Tackles per 90',
#        'Total Duels Won per 90', 'Save Percentage', 'Clean Sheets',
#        'Brand Sponsor/Brand Used'],
#       dtype='object')

# %%
df.astype
# Out:
# <bound method NDFrame.astype of     Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 0      Argentina              2                    Adidas       GK
# 1      Argentina              2                    Adidas       GK
# 2      Argentina              2                    Adidas       GK
# 3      Argentina              2                    Adidas       DF
# 4      Argentina              2                    Adidas       DF
# ..           ...            ...                       ...      ...
# 809       Canada             53                      Nike       FW
# 810       Canada             53                      Nike       FW
# 811       Canada             53                      Nike       FW
# 812       Canada             53                      Nike       FW
# 813       Canada             53                      Nike       FW
#
#      National Team Jersey Number    Player DOB          Club   \
# 0                           23.0   Sep 2, 1992    Aston Villa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nationality                  814 non-null    object
#  1   FIFA Ranking                 814 non-null    int64
#  2   National Team Kit Sponsor    813 non-null    object
#  3   Position                     814 non-null    object
#  4   National Team Jersey Number  813 non-null    float64
#  5   Player DOB                   814 non-null    object
#  6   Club                         814 non-null    object
#  7   Player Name                  814 non-null    object
#  8    Appearances                 814 non-null    object
#  9   Goals Scored                 813 non-null    object
#  10  Assists Provided             813 non-null    object
#  11  Dribbles per 90              813 non-null    object
#  12  Interceptions per 90         813 non-null    object
# ...

# %%
(df["Nationality "].value_counts()
# Out:
# Argentina       26
# South Korea     26
# Uruguay         26
# Ghana           26
# Germany         26
# Tunisia         26
# Denmark         26
# Mexico          26
# Qatar           26
# Spain           26
# Ecuador         26
# Canada          26
# Australia       26
# Netherlands     26
# Brazil          26
# Croatia         26
# Portugal        26
# Morocco         26
# Poland          26
# Iran            25
# France          25
# Switzerland     25
# USA             25
# England         25
# Costa Rica      25
# Belgium         25
# Wales           25
# Serbia          24
# Senegal         24
# Cameroon        24
# Japan           24
# Saudi Arabia    24
# Name: Nationality , dtype: int64

# %%
df["Brand Sponsor/Brand Used"].value_counts()
# Out:
# Nike            424
# Adidas          259
# Puma             92
# Mizuno           14
# New Balance       8
# Lotto             3
# Under Armour      3
# NIke              2
# Pirma             2
# Nike              1
# Asics             1
# Umbro             1
# N.A               1
# Charly            1
# Pima              1
# Name: Brand Sponsor/Brand Used, dtype: int64

# %%
df["Goals Scored "].value_counts()
# Out:
# 0      469
# N.A    147
# 1       86
# -       81
# 2       18
# 3        7
# 4        2
# 7        1
# 8        1
# N,A      1
# Name: Goals Scored , dtype: int64

# %%
df=df.astype('string')

# %%
df.dtypes
# Out:
# Nationality                    string
# FIFA Ranking                   string
# National Team Kit Sponsor      string
# Position                       string
# National Team Jersey Number    string
# Player DOB                     string
# Club                           string
# Player Name                    string
#  Appearances                   string
# Goals Scored                   string
# Assists Provided               string
# Dribbles per 90                string
# Interceptions per 90           string
# Tackles per 90                 string
# Total Duels Won per 90         string
# Save Percentage                string
# Clean Sheets                   string
# Brand Sponsor/Brand Used       string
# dtype: object

# %%
df[['Save Percentage','Clean Sheets','Player DOB','Position','Goals Scored ']]
# Out:
#     Save Percentage Clean Sheets    Player DOB Position Goals Scored
# 0            46.67%          43%   Sep 2, 1992       GK             0
# 1                 -            -  Oct 16, 1986       GK             -
# 2                 -            -  May 20, 1992       GK             -
# 3                 -            -  Feb 12, 1988       DF             0
# 4                 -            -  Oct 28, 1991       DF             0
# ..              ...          ...           ...      ...           ...
# 809               -            -  Apr 17, 1995       FW             0
# 810               -            -   Nov 2, 2000       FW             1
# 811               -            -  Jan 14, 2000       FW             0
# 812               -            -  Sep 27, 1999       FW             0
# 813               -            -  Sep 21, 1998       FW           N.A
#
# [814 rows x 5 columns]

# %%
df['Interceptions per 90'].astype(bool)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 809    True
# 810    True
# 811    True
# 812    True
# 813    True
# Name: Interceptions per 90, Length: 814, dtype: bool

# %%
df
# Out:
#     Nationality  FIFA Ranking  National Team Kit Sponsor Position  \
# 0      Argentina             2                    Adidas       GK
# 1      Argentina             2                    Adidas       GK
# 2      Argentina             2                    Adidas       GK
# 3      Argentina             2                    Adidas       DF
# 4      Argentina             2                    Adidas       DF
# ..           ...           ...                       ...      ...
# 809       Canada            53                      Nike       FW
# 810       Canada            53                      Nike       FW
# 811       Canada            53                      Nike       FW
# 812       Canada            53                      Nike       FW
# 813       Canada            53                      Nike       FW
#
#     National Team Jersey Number    Player DOB          Club   \
# 0                          23.0   Sep 2, 1992    Aston Villa
# ...

# %%
player= df["Player Name "]

# %%
player
# Out:
# 0      Emiliano Martinez
# 1          Franco Armani
# 2         Geronimo Rulli
# 3       Nicolas Otamendi
# 4           Marcos Acuna
#              ...
# 809           Cyle Larin
# 810      Alphonso Davies
# 811       Jonathan David
# 812          Liam Millar
# 813             Ike Ugbo
# Name: Player Name , Length: 814, dtype: string

# %%
clup = df["Club "]

# %%
plt.plot(df['Goals Scored '])

# %%
import matplotlib.pyplot as plt

# %%
df.isna().sum()
# Out:
# Nationality                    0
# FIFA Ranking                   0
# National Team Kit Sponsor      0
# Position                       0
# National Team Jersey Number    0
# Player DOB                     0
# Club                           0
# Player Name                    0
#  Appearances                   0
# Goals Scored                   0
# Assists Provided               0
# Dribbles per 90                0
# Interceptions per 90           0
# Tackles per 90                 0
# Total Duels Won per 90         0
# Save Percentage                0
# Clean Sheets                   0
# Brand Sponsor/Brand Used       0
# dtype: int64

# %%
df
# Out:
#     Nationality  FIFA Ranking  National Team Kit Sponsor Position  \
# 0      Argentina             2                    Adidas       GK
# 1      Argentina             2                    Adidas       GK
# 2      Argentina             2                    Adidas       GK
# 3      Argentina             2                    Adidas       DF
# 4      Argentina             2                    Adidas       DF
# ..           ...           ...                       ...      ...
# 809       Canada            53                      Nike       FW
# 810       Canada            53                      Nike       FW
# 811       Canada            53                      Nike       FW
# 812       Canada            53                      Nike       FW
# 813       Canada            53                      Nike       FW
#
#     National Team Jersey Number    Player DOB          Club   \
# 0                          23.0   Sep 2, 1992    Aston Villa
# ...

# %%
df.describe()
# Out:
#        Nationality  FIFA Ranking  National Team Kit Sponsor Position  \
# count           814           814                       814      814
# unique           32            32                        11        4
# top       Argentina             2                      Nike       DF
# freq             26            26                       331      262
#
#        National Team Jersey Number    Player DOB      Club   \
# count                          814           814        814
# unique                          27           771        319
# top                           16.0  May 31, 1989  Barcelona
# freq                            33             3         16
#
#              Player Name   Appearances Goals Scored  Assists Provided   \
# count                 814          814           814               814
# unique                814           11            11                 8
# top     Emiliano Martinez            3             0                 0
# ...

# %%
df["Club "].value_counts().head(20)
# Out:
# Barcelona            16
# Manchester City      16
# Bayern Munich        16
# Manchester United    13
# Al-Sadd              13
# PSG                  12
# Atletico Madrid      12
# Chelsea              12
# Real Madrid          12
# Al-Hilal             12
# Ajax                 11
# Juventus             11
# Borussia Dortmund    11
# Arsenal               9
# Sevilla               9
# Tottenham             8
# Al-Duhail             8
# Brighton              8
# Club Brugge           8
# Rennes                8
# Name: Club , dtype: Int64

# %%
df['Goals Scored '].value_counts()
# Out:
# 0      469
# N.A    147
# 1       86
# -       81
# 2       18
# 3        7
# 4        2
# 7        1
# 8        1
# N,A      1
# nan      1
# Name: Goals Scored , dtype: Int64

# %%
socer=df[['Player Name ','Goals Scored '] ]

# %%
df['Goals Scored ']=df['Goals Scored '].str.replace("N.A", "nan", case=False, regex=True)

# %%
df['Goals Scored '].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 809    False
# 810    False
# 811    False
# 812    False
# 813    False
# Name: Goals Scored , Length: 814, dtype: bool

# %%
df['Goals Scored ']=df['Goals Scored '].str.replace("nan", "0", case=False, regex=True)

# %%
df['Goals Scored '].value_counts()
# Out:
# 0    699
# 1     86
# 2     18
# 3      7
# 4      2
# 7      1
# 8      1
# Name: Goals Scored , dtype: Int64

# %%
socer=df[['Player Name ','Goals Scored '] ]

# %%
df['Goals Scored ']=df['Goals Scored '].str.replace("-", "0", case=False, regex=True)

# %%
df[' Appearances ']=df[' Appearances'].str.replace("-", "0", case=False, regex=True)

# %%
socer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player Name    814 non-null    string
#  1   Goals Scored   814 non-null    string
# dtypes: string(2)
# memory usage: 12.8 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nationality                  814 non-null    string
#  1   FIFA Ranking                 814 non-null    string
#  2   National Team Kit Sponsor    814 non-null    string
#  3   Position                     814 non-null    string
#  4   National Team Jersey Number  814 non-null    string
#  5   Player DOB                   814 non-null    string
#  6   Club                         814 non-null    string
#  7   Player Name                  814 non-null    string
#  8    Appearances                 814 non-null    string
#  9   Goals Scored                 814 non-null    int32
#  10  Assists Provided             814 non-null    string
#  11  Dribbles per 90              814 non-null    string
#  12  Interceptions per 90         814 non-null    string
# ...

# %%
df['Goals Scored ']=df['Goals Scored '].astype(int)

# %%
socer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player Name    814 non-null    string
#  1   Goals Scored   814 non-null    int32
# dtypes: int32(1), string(1)
# memory usage: 9.7 KB

# %%
socer['Goals Scored ']=socer['Goals Scored '].astype(int)
# Out:
# C:\Users\fg\AppData\Local\Temp\ipykernel_3040\3325508940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   socer['Goals Scored ']=socer['Goals Scored '].astype(int)

# %%
df
# Out:
#     Nationality  FIFA Ranking  National Team Kit Sponsor Position  \
# 0      Argentina             2                    Adidas       GK
# 1      Argentina             2                    Adidas       GK
# 2      Argentina             2                    Adidas       GK
# 3      Argentina             2                    Adidas       DF
# 4      Argentina             2                    Adidas       DF
# ..           ...           ...                       ...      ...
# 809       Canada            53                      Nike       FW
# 810       Canada            53                      Nike       FW
# 811       Canada            53                      Nike       FW
# 812       Canada            53                      Nike       FW
# 813       Canada            53                      Nike       FW
#
#     National Team Jersey Number    Player DOB          Club   \
# 0                          23.0   Sep 2, 1992    Aston Villa
# ...

# %%
df["Goals Scored "].idxmax()
# Out:
# 45

# %%
df.loc[45]    # the socker of world cup
# Out:
# Nationality                           France
# FIFA Ranking                               3
# National Team Kit Sponsor               Nike
# Position                                  FW
# National Team Jersey Number             10.0
# Player DOB                      Dec 20, 1998
# Club                                     PSG
# Player Name                    Kylian Mbappe
#  Appearances                               7
# Goals Scored                               8
# Assists Provided                           2
# Dribbles per 90                         7.24
# Interceptions per 90                    0.00
# Tackles per 90                          0.00
# Total Duels Won per 90                  5.12
# Save Percentage                            -
# Clean Sheets                               -
# Brand Sponsor/Brand Used                Nike
# Name: 45, dtype: object

# %%
df['Player Name '].head(30)
# Out:
# 0       Emiliano Martinez
# 1           Franco Armani
# 2          Geronimo Rulli
# 3        Nicolas Otamendi
# 4            Marcos Acuna
# 5      Nicolas Tagliafico
# 6         German Pezzella
# 7           Nahuel Molina
# 8         Gonzalo Montiel
# 9              Juan Foyth
# 10        Cristian Romero
# 11      Lisandro Martinez
# 12        Leandro Paredes
# 13        Rodrigo De Paul
# 14        Guido Rodriguez
# 15      Exequiel Palacios
# 16    Alexis Mac Allister
# 17         Enzo Fernandez
# 18        Alejandro Gomez
# 19         Lionel Messi 🐐
# 20       Lautaro Martinez
# 21           Paulo Dybala
# 22          Thiago Almada
# 23         Julian Alvarez
# 24         Angel Di Maria
# 25           Angel Correa
# 26            Hugo Lloris
# 27        Alphonse Areola
# 28         Steve Mandanda
# 29        Benjamin Pavard
# Name: Player Name , dtype: string

# %%
df.loc[19]  # the best player in the world cup
# Out:
# Nationality                         Argentina
# FIFA Ranking                                2
# National Team Kit Sponsor              Adidas
# Position                                   FW
# National Team Jersey Number              10.0
# Player DOB                       Jun 24, 1987
# Club                                      PSG
# Player Name                    Lionel Messi 🐐
#  Appearances                                7
# Goals Scored                                7
# Assists Provided                            3
# Dribbles per 90                          3.78
# Interceptions per 90                     0.00
# Tackles per 90                           0.65
# Total Duels Won per 90                   6.39
# Save Percentage                             -
# Clean Sheets                                -
# Brand Sponsor/Brand Used               Adidas
# Name: 19, dtype: object

# %%
df.loc[17] # the best young player
# Out:
# Nationality                         Argentina
# FIFA Ranking                                2
# National Team Kit Sponsor              Adidas
# Position                                   MF
# National Team Jersey Number              24.0
# Player DOB                       Jan 17, 2001
# Club                                  Benfica
# Player Name                    Enzo Fernandez
#  Appearances                                7
# Goals Scored                                1
# Assists Provided                            1
# Dribbles per 90                          0.80
# Interceptions per 90                     0.48
# Tackles per 90                           3.52
# Total Duels Won per 90                   7.83
# Save Percentage                           nan
# Clean Sheets                                -
# Brand Sponsor/Brand Used                 Nike
# Name: 17, dtype: object

# %%
plt.plot(df['Goals Scored '])

# %%
plt.plot(df[' Appearances'])

# %%
df[' Appearances'].value_counts()
# Out:
# 0    194
# 3    193
# 1    117
# 2    113
# 4    112
# 5     35
# 7     27
# 6     23
# Name:  Appearances, dtype: Int64

# %%
df[' Appearances']=df[' Appearances'].str.replace("-", "0", case=False, regex=True)

# %%
df.columns
# Out:
# Index(['Nationality ', 'FIFA Ranking ', 'National Team Kit Sponsor',
#        'Position', 'National Team Jersey Number', 'Player DOB', 'Club ',
#        'Player Name ', ' Appearances', 'Goals Scored ', 'Assists Provided ',
#        'Dribbles per 90', 'Interceptions per 90', 'Tackles per 90',
#        'Total Duels Won per 90', 'Save Percentage', 'Clean Sheets',
#        'Brand Sponsor/Brand Used', ' Appearances '],
#       dtype='object')

# %%
plt.plot(df['FIFA Ranking '])

# %%
plt.scatter(df['Goals Scored '],df['Player Name '])
# Out:
# c:\Users\fg\anaconda3\envs\PycharmProjects\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128016 (\N{GOAT}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\fg\anaconda3\envs\PycharmProjects\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128016 (\N{GOAT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.bar(df['Goals Scored '],df['Player Name '])
# Out:
# <BarContainer object of 814 artists>
# c:\Users\fg\anaconda3\envs\PycharmProjects\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128016 (\N{GOAT}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\fg\anaconda3\envs\PycharmProjects\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128016 (\N{GOAT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
