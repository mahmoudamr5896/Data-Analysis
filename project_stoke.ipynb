# %% [markdown]
# ### import library :

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
amzon = pd.read_csv('NOTE BOOK/AMZN.csv')

# %% [markdown]
# #### loading data :

# %%
aple = pd.read_csv('AAPL.csv')
amzon = pd.read_csv('AMZN.csv')
meta = pd.read_csv('META.csv')
google = pd.read_csv('GOOGL.csv')

# %%
aple.set_index(aple['Date'])
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2010-01-04  2010-01-04    7.622500    7.660714    7.585000    7.643214
# 2010-01-05  2010-01-05    7.664286    7.699643    7.616071    7.656429
# 2010-01-06  2010-01-06    7.656429    7.686786    7.526786    7.534643
# 2010-01-07  2010-01-07    7.562500    7.571429    7.466071    7.520714
# 2010-01-08  2010-01-08    7.510714    7.571429    7.466429    7.570714
# ...                ...         ...         ...         ...         ...
# 2022-12-22  2022-12-22  134.350006  134.559998  130.300003  132.229996
# 2022-12-23  2022-12-23  130.919998  132.419998  129.639999  131.860001
# 2022-12-27  2022-12-27  131.380005  131.410004  128.720001  130.029999
# 2022-12-28  2022-12-28  129.669998  131.029999  125.870003  126.040001
# 2022-12-29  2022-12-29  127.989998  130.479996  127.730003  129.610001
#
#              Adj Close     Volume
# Date
# 2010-01-04    6.515213  493729600
# ...

# %%
aple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3271 non-null   object
#  1   Open       3271 non-null   float64
#  2   High       3271 non-null   float64
#  3   Low        3271 non-null   float64
#  4   Close      3271 non-null   float64
#  5   Adj Close  3271 non-null   float64
#  6   Volume     3271 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 179.0+ KB

# %%
aple .describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     51.274171    51.845876    50.708548    51.297154    49.445122
# std      47.316509    47.926721    46.720115    47.344344    47.810585
# min       6.870357     7.000000     6.794643     6.858929     5.846675
# 25%      18.965894    19.121607    18.779999    18.965536    16.625739
# 50%      29.745001    29.980000    29.555000    29.812500    27.385101
# 75%      56.897499    57.256248    56.435000    56.761250    54.876044
# max     182.630005   182.940002   179.119995   182.009995   180.959732
#
#              Volume
# count  3.271000e+03
# mean   2.563255e+08
# std    2.225768e+08
# min    3.519590e+07
# 25%    1.023724e+08
# 50%    1.666740e+08
# 75%    3.457554e+08
# max    1.880998e+09

# %%
aple.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
sns.pairplot(aple)

# %%
sns.pairplot(amzon)

# %%
sns.pairplot(google)

# %%
sns.pairplot(meta)

# %%
# !pip install plotly

# %%
import plotly.tools

# %%
import plotly.colors

# %%
amzon.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     58.937204    59.610805    58.183281    58.905287    58.905287
# std      54.138607    54.785319    53.410691    54.085034    54.085034
# min       5.296500     5.564500     5.290000     5.430500     5.430500
# 25%      13.343750    13.474500    13.197000    13.326250    13.326250
# 50%      36.325001    36.500000    36.027500    36.382500    36.382500
# 75%      93.025002    94.177250    92.023250    93.138001    93.138001
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  3.271000e+03
# mean   8.833999e+07
# std    5.309249e+07
# min    1.762600e+07
# 25%    5.610700e+07
# 50%    7.459200e+07
# 75%    1.037120e+08
# max    8.484220e+08

# %%
google.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   112.008338  113.580572  110.380915  111.933412  111.933412
# std     16.061858   16.094546   15.726139   15.899375   15.899375
# min     85.400002   86.519997   83.339996   83.430000   83.430000
# 25%     98.204998   99.779999   97.069997   98.455000   98.455000
# 50%    111.491753  113.312748  109.965000  111.622749  111.622749
# 75%    121.713623  122.960249  119.747500  122.125252  122.125252
# max    151.250000  151.546494  145.522507  148.000000  148.000000
#
#              Volume
# count  2.520000e+02
# mean   3.450729e+07
# std    1.334196e+07
# min    9.701400e+06
# 25%    2.597800e+07
# 50%    3.173255e+07
# 75%    3.991450e+07
# max    1.232000e+08

# %%
meta.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2688.000000  2688.000000  2688.000000  2688.000000  2688.000000
# mean    147.874275   149.757980   146.003795   147.913244   147.913244
# std      86.734656    87.818979    85.682869    86.763257    86.763257
# min      18.080000    18.270000    17.549999    17.730000    17.730000
# 25%      77.967500    78.627499    77.145001    77.980000    77.980000
# 50%     141.620002   143.415000   140.550003   142.065002   142.065002
# 75%     191.070000   193.807499   188.255001   190.854996   190.854996
# max     381.679993   384.329987   378.809998   382.179993   382.179993
#
#              Volume
# count  2.688000e+03
# mean   3.117815e+07
# std    2.713267e+07
# min    5.913100e+06
# 25%    1.622585e+07
# 50%    2.323900e+07
# 75%    3.603725e+07
# max    5.735764e+08

# %%
aple.set_index(aple['Date']=='2022-12-29',)
#\aple(aple['date']=='2022')
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# Date
# False  2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# False  2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526476
# False  2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422664
# False  2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410790
# False  2010-01-08    7.510714    7.571429    7.466429    7.570714    6.453412
# ...           ...         ...         ...         ...         ...         ...
# False  2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# False  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# False  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# False  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# True   2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
#
#           Volume
# Date
# ...

# %%
date_aple  =aple.set_index(aple['Date'])
date_aple
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2010-01-04  2010-01-04    7.622500    7.660714    7.585000    7.643214
# 2010-01-05  2010-01-05    7.664286    7.699643    7.616071    7.656429
# 2010-01-06  2010-01-06    7.656429    7.686786    7.526786    7.534643
# 2010-01-07  2010-01-07    7.562500    7.571429    7.466071    7.520714
# 2010-01-08  2010-01-08    7.510714    7.571429    7.466429    7.570714
# ...                ...         ...         ...         ...         ...
# 2022-12-22  2022-12-22  134.350006  134.559998  130.300003  132.229996
# 2022-12-23  2022-12-23  130.919998  132.419998  129.639999  131.860001
# 2022-12-27  2022-12-27  131.380005  131.410004  128.720001  130.029999
# 2022-12-28  2022-12-28  129.669998  131.029999  125.870003  126.040001
# 2022-12-29  2022-12-29  127.989998  130.479996  127.730003  129.610001
#
#              Adj Close     Volume
# Date
# 2010-01-04    6.515213  493729600
# ...

# %%
(aple['Open'].max())
# Out:
# 182.630005

# %%
import datetime as dt

# %%
aple['Date']= pd.to_datetime(aple['Date'])

# %%
aple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# ## the most stoke Closed in four companies :
#  - amzon
#  - google
#  - meta
#  -aple

# %%
(amzon['Close'].max()),(google['Close'].max()),(meta['Close'].max()),(aple['Close'].max())
# Out:
# (186.570496, 148.0, 382.179993, 182.009995)

# %% [markdown]
# ## the most stoke opened in four companies :
#  - amzon
#  - google
#  - meta
#  -aple

# %%
(amzon['Open'].max()),(google['Open'].max()),(meta['Open'].max()),(aple['Open'].max())
# Out:
# (187.199997, 151.25, 381.679993, 182.630005)

# %% [markdown]
# ## the most stoke be High in four companies :
#  - amzon
#  - google
#  - meta
#  -aple

# %%
(amzon['High'].max()),(google['High'].max()),(meta['High'].max()),(aple['High'].max())
# Out:
# (188.654007, 151.546494, 384.329987, 182.940002)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1412\2596219695.py in <module>
# ----> 1 aple(aple['Date']==2022-12-29)
#
# TypeError: 'DataFrame' object is not callable

# %%
amzon.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
amzon['Date']= pd.to_datetime(amzon['Date'])

# %%
amzon.dtypes
# Out:
# Date         string
# Open         string
# High         string
# Low          string
# Close        string
# Adj Close    string
# Volume       string
# dtype: object

# %%
open =aple[['Open','Close','Date']]

# %%
open.iplot(kind='histogram', filename='simple-histogram-chart')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1412\1340848040.py in <module>
# ----> 1 open.iplot(kind='histogram', filename='simple-histogram-chart')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.isna().sum()
# Out:
# Open     0
# Close    0
# dtype: int64

# %%
df=open#.astype('float')

# %%
df['Open'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# dtype: int64

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# dtype: object

# %%
df1 = pd.DataFrame(data=df,dtype='float64')

# %%
df1.dtypes
# Out:
# Open     float64
# Close    float64
# dtype: object

# %%
plt.plot(df)
plt.show()

# %%
df.set_index(df['Date'])
# Out:
#                   Open       Close       Date
# Date
# 2010-01-04    7.622500    7.643214 2010-01-04
# 2010-01-05    7.664286    7.656429 2010-01-05
# 2010-01-06    7.656429    7.534643 2010-01-06
# 2010-01-07    7.562500    7.520714 2010-01-07
# 2010-01-08    7.510714    7.570714 2010-01-08
# ...                ...         ...        ...
# 2022-12-22  134.350006  132.229996 2022-12-22
# 2022-12-23  130.919998  131.860001 2022-12-23
# 2022-12-27  131.380005  130.029999 2022-12-27
# 2022-12-28  129.669998  126.040001 2022-12-28
# 2022-12-29  127.989998  129.610001 2022-12-29
#
# [3271 rows x 3 columns]

# %%
df.iloc[3250:,]
# Out:
#             Open       Close       Date
# 3250  141.399994  148.029999 2022-11-30
# 3251  148.210007  148.309998 2022-12-01
# 3252  145.960007  147.809998 2022-12-02
# 3253  147.770004  146.630005 2022-12-05
# 3254  147.070007  142.910004 2022-12-06
# 3255  142.190002  140.940002 2022-12-07
# 3256  142.360001  142.649994 2022-12-08
# 3257  142.339996  142.160004 2022-12-09
# 3258  142.699997  144.490005 2022-12-12
# 3259  149.500000  145.470001 2022-12-13
# 3260  145.350006  143.210007 2022-12-14
# 3261  141.110001  136.500000 2022-12-15
# 3262  136.690002  134.509995 2022-12-16
# 3263  135.110001  132.369995 2022-12-19
# 3264  131.389999  132.300003 2022-12-20
# 3265  132.979996  135.449997 2022-12-21
# 3266  134.350006  132.229996 2022-12-22
# 3267  130.919998  131.860001 2022-12-23
# 3268  131.380005  130.029999 2022-12-27
# 3269  129.669998  126.040001 2022-12-28
# 3270  127.989998  129.610001 2022-12-29
